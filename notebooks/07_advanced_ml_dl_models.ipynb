# %% [markdown]
# # 07 — Advanced ML & DL Models
#
# **Project:** Predicting Corporate GHG Intensity
# **Purpose:** Train and evaluate advanced non-linear estimators (Tree Ensembles and PyTorch MLP).
#
# ---

# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.feature_engineering import FeatureEngineer
from src.models import ModelPipeline

INTERIM_DIR = PROJECT_ROOT / "data" / "interim"

# %% [markdown]
# ### 1. Load Processed Data

# %%
linked_df = pd.read_csv(INTERIM_DIR / "linked_panel.csv")

fe = FeatureEngineer()
raw_df = fe.build_raw_features(linked_df)

pipeline = ModelPipeline(target="scope1_intensity_rev", group_col="cik")
train_df, test_df, features = pipeline.prepare_train_test(raw_df)
# Out:
# 2026-09-12 22:00:19,064 - INFO - Train years: [np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019)] (3803 raw rows), Test years: [np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023)] (2675 raw rows)
# 2026-09-12 22:00:19,449 - INFO - Heckman Stage 1 (Probit, train-fold fit) — pseudo-R²: 0.4261, N = 3803, features = ['size', 'leverage', 'roa', 'high_emission_naics', 'sector_code']
# 2026-09-12 22:00:19,688 - INFO - Reporting subset: 1839 train / 1216 test firm-years, 28 features, target = scope1_intensity_rev

# %% [markdown]
# ### 2. Fit Tree Ensembles & Neural Network MLP
# We fit Random Forest, XGBoost, LightGBM, and the PyTorch Multi-Layer Perceptron (MLP) with hyperparameter tuning.

# %%
results_df = pipeline.train_all_models(train_df, test_df, features, tune=True)
results_df[["model", "test_rmse", "test_r2", "test_mae"]]
# Out:
# 2026-09-12 22:00:21,847 - INFO -   Ridge best params: {'alpha': 100.0}
# 2026-09-12 22:00:21,878 - INFO -   Lasso best params: {'alpha': 1.0}
# 2026-09-12 22:00:21,923 - INFO -   ElasticNet best params: {'alpha': 1.0, 'l1_ratio': 0.5}
# 2026-09-12 22:00:40,538 - INFO -   RandomForest best params: {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 2}
# 2026-09-12 22:00:53,598 - INFO -   XGBoost best params: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.05, 'subsample': 0.8}
# E:\Research_Projects\predicting-corporate-ghg-intensity\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# E:\Research_Projects\predicting-corporate-ghg-intensity\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# ### Discussion & Next Steps
# Non-linear estimators (e.g. Tree Ensembles, Neural Net) capture complex interactions and sector thresholds better than linear models. In the next notebook, we explore model interpretability via SHAP and execute robustness testing.
